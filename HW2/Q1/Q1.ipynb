# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %% [markdown]
# # Question 1:

# %% [markdown]
# # part 2:

# %%
#define image1 here
import numpy as np
import pandas as pd

image1_data = np.array([[141, 0, 138, 143, 143, 143, 144],
                [141, 140, 140, 142, 142, 143, 143],
                [140, 145, 145, 144, 142, 142, 145],
                [141, 141, 141, 143, 142, 141, 143],
                [139, 140, 141, 141, 142, 143, 144]])
unique, counts = np.unique(image1_data, return_counts=True)
df = pd.DataFrame({'Number': unique, 'Count': counts})
print(df)
# Out:
#    Number  Count
# 0       0      1
# 1     138      1
# 2     139      1
# 3     140      4
# 4     141      8
# 5     142      6
# 6     143      8
# 7     144      3
# 8     145      3

# %%
import matplotlib.pyplot as plt

image1 = np.array(image1_data).flatten()
min_val = image1.min()
max_val = image1.max()
plt.figure(figsize=(10, 6))
plt.hist(image1, bins=np.arange(min_val, max_val + 10, 1), edgecolor='black', color='skyblue')
plt.xlabel('Number')
plt.ylabel('Frequency')
plt.title('Histogram of Image Data')
plt.xticks(np.arange(min_val, max_val + 10, 10))
plt.show()

# %% [markdown]
# after scratching image1

# %%
scratch_image1 = (255 * (image1_data - np.min(image1_data)))//(np.max(image1_data) - np.min(image1_data))
unique, counts = np.unique(scratch_image1, return_counts=True)
df = pd.DataFrame({'Number': unique, 'Count': counts})
print(df)
# Out:
#    Number  Count
# 0       0      1
# 1     242      1
# 2     244      1
# 3     246      4
# 4     247      8
# 5     249      6
# 6     251      8
# 7     253      3
# 8     255      3

# %%
import matplotlib.pyplot as plt

image1_1 = np.array(scratch_image1).flatten()
min_val = image1_1.min()
max_val = image1_1.max()
plt.figure(figsize=(10, 6))
plt.hist(image1_1, bins=np.arange(min_val, max_val + 10, 1), edgecolor='black', color='skyblue')
plt.xlabel('Number')
plt.ylabel('Frequency')
plt.title('Histogram of Image Data after scratching')
plt.xticks(np.arange(min_val, max_val + 10, 10))
plt.show()

# %% [markdown]
# After cutting [130, 150]: *italicized text*

# %%
image1 = np.array(image1_data)
image1_clipped = np.clip(image1, 130, 150)
print(image1_clipped)
unique, counts = np.unique(image1_clipped, return_counts=True)
df = pd.DataFrame({'Number': unique, 'Count': counts})
print(df)
# Out:
# [[141 130 138 143 143 143 144]
#  [141 140 140 142 142 143 143]
#  [140 145 145 144 142 142 145]
#  [141 141 141 143 142 141 143]
#  [139 140 141 141 142 143 144]]
#    Number  Count
# 0     130      1
# 1     138      1
# 2     139      1
# 3     140      4
# 4     141      8
# 5     142      6
# 6     143      8
# 7     144      3
# 8     145      3

# %%
import matplotlib.pyplot as plt

image1_2 = np.array(image1_clipped).flatten()
min_val = image1_2.min()
max_val = image1_2.max()
plt.figure(figsize=(10, 6))
plt.hist(image1_2, bins=np.arange(min_val, max_val + 10, 1), edgecolor='black', color='skyblue')
plt.xlabel('Number')
plt.ylabel('Frequency')
plt.title('Histogram of Image Data after cutting')
plt.xticks(np.arange(min_val, max_val + 10, 2))
plt.show()

# %% [markdown]
# After cutting between 140, 145:

# %%
image1_clipped = np.clip(image1, 140, 145)
print(image1_clipped)
unique, counts = np.unique(image1_clipped, return_counts=True)
df = pd.DataFrame({'Number': unique, 'Count': counts})
print(df)
# Out:
# [[141 140 140 143 143 143 144]
#  [141 140 140 142 142 143 143]
#  [140 145 145 144 142 142 145]
#  [141 141 141 143 142 141 143]
#  [140 140 141 141 142 143 144]]
#    Number  Count
# 0     140      7
# 1     141      8
# 2     142      6
# 3     143      8
# 4     144      3
# 5     145      3

# %%
image1_3 = np.array(image1_clipped).flatten()
min_val = image1_3.min()
max_val = image1_3.max()
plt.figure(figsize=(10, 6))
plt.hist(image1_3, bins=np.arange(min_val, max_val + 10, 1), edgecolor='black', color='skyblue')
plt.xlabel('Number')
plt.ylabel('Frequency')
plt.title('Histogram of Image Data after cutting [140, 145]')
plt.xticks(np.arange(min_val, max_val + 10, 2))
plt.show()

# %%
#code here
#first define a function for calculating histogram
#you are free to use libraries
def calc_hist(image):
    '''
    you are free to use libraries
    calculate image histogram
    input(s):
      image (ndarray): input image
    output(s):
      hist (ndarray): computed input image histogram
    '''
    hist = np.zeros(256)
    for row in image:
      for pixel in row:
        hist[pixel] += 1
    return hist

# %%
#dont change this cell
plt.imshow(image1,cmap='gray',vmin=0,vmax=255)
plt.figure()
plt.plot(calc_hist(image1))
plt.title('histogram')
# Out:
# Text(0.5, 1.0, 'histogram')

# %%
#code here
#define a function (stretch) for stretching(input:image , output: stretched image)

def stretch_hist(image):
  '''
  don't use libraries
  input(s):
    image (ndarray): input image
  output(s):
    output_image (ndarray): enhanced image with histogram stretching
  '''
  output_image = image.copy()
  # Start
  min_val = np.min(output_image)
  max_val = np.max(output_image)
  output_image = (255*((image - min_val) / (max_val - min_val))).astype('uint8')
  # End
  return output_image

# %%
#dont change this cell
plt.imshow(stretch_hist(image1),cmap='gray',vmin=0,vmax=255)
plt.figure()
plt.plot(calc_hist(stretch_hist(image1)))
plt.title('stretched histogram')
# Out:
# Text(0.5, 1.0, 'stretched histogram')

# %%
#code here
#define a function (Clip) for Clipping(input:image , output: Clipped image)

def clip_hist(image, min_value, max_value):
  '''
  don't use libraries
  input(s):
    image (ndarray): input image
    min_value : min value of the histogram which you wanna clip.
    max_value : max value of the histogram which you wanna clip.
  output(s):
    output_image (ndarray): enhanced image with histogram clipping
  '''
  output_image = image.copy()
  # Start
  output_image = np.clip(image, min_value, max_value)
  # End
  return output_image

# %%
#dont change this cell
# min_value = # your min value here
min_value = 130
# max_value = # your max value here
max_value = 150
plt.imshow(clip_hist(image1, min_value, max_value),cmap='gray',vmin=0,vmax=255)
plt.figure()
plt.plot(calc_hist(clip_hist(image1,min_value, max_value)))
plt.title('clipped histogram')
# Out:
# Text(0.5, 1.0, 'clipped histogram')

# %%
#dont change this cell
# min_value = # your min value here
min_value = 140
# max_value = # your max value here
max_value = 145
plt.imshow(clip_hist(image1, min_value, max_value),cmap='gray',vmin=0,vmax=255)
plt.figure()
plt.plot(calc_hist(clip_hist(image1,min_value, max_value)))
plt.title('clipped histogram')
# Out:
# Text(0.5, 1.0, 'clipped histogram')

# %% [markdown]
# # part3

# %%
# first read the image and show it.(image2)
input_image = cv2.imread('image2.png')
image_rgb = cv2.cvtColor(input_image, cv2.COLOR_BGR2RGB)
plt.imshow(image_rgb)
plt.axis('off')
plt.show()

# %%
plt.plot(calc_hist(clip_hist(input_image, 0, 255)))
plt.title('clipped histogram')
# Out:
# Text(0.5, 1.0, 'clipped histogram')

# %%
# And visualize the histogram of the stretched image

stretched_image = stretch_hist(input_image)
stretched_image_hist = calc_hist(stretched_image)
plt.figure()
plt.plot(stretched_image_hist)
plt.title('Stretched Histogram')
plt.show()

# %%
#use clip_hist function to improve quality of the image and show it

plt.imshow(stretched_image, cmap='gray', vmin=0, vmax=255)
plt.title('Stretched Image')
plt.axis('off')
plt.show()

# %%
min_value = 100
max_value = 255
plt.imshow(clip_hist(input_image, min_value, max_value), cmap = 'gray', vmin = 0, vmax = 255)
plt.figure()
plt.plot(calc_hist(clip_hist(input_image, min_value, max_value)))
plt.title('clipped histogram')
# Out:
# Text(0.5, 1.0, 'clipped histogram')

# %%
min_value = 70
max_value = 150
plt.imshow(stretch_hist(clip_hist(input_image, min_value, max_value)), cmap = 'gray', vmin = 0, vmax = 255)
plt.figure()
plt.plot(calc_hist(stretch_hist(clip_hist(input_image, min_value, max_value))))
plt.title('clipped histogram')
# Out:
# Text(0.5, 1.0, 'clipped histogram')
