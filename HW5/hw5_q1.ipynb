# %%
import cv2
from google.colab.patches import cv2_imshow
import os
import matplotlib.pyplot as plt
from PIL import Image
from skimage import measure
import numpy as np

# %%
directory = "images"
filename = "q1.png"
file_path = os.path.join(directory, filename)
image = Image.open(file_path)

# %%
# to convert an image to gray scale
gray_image = image.convert("L")
plt.figure(figsize=(8, 6))

# Original Image
plt.subplot(1, 2, 1)
plt.title("Original Image")
plt.imshow(image)
plt.axis("off")

# Grayscale Image
plt.subplot(1, 2, 2)
plt.title("Grayscale Image")
plt.imshow(gray_image, cmap="gray")
plt.axis("off")

plt.show()

# %% [markdown]
# according to the above code we realize that our picture is in grayscale.

# %%
image_gray = image.convert('L')
image_array = np.array(image_gray)

# Threshold the image to create a binary image
binary_image = image_array > 0
# Find connected components in the binary image
label_image = measure.label(binary_image)
# Count the number of connected components
num_components = np.max(label_image)

plt.subplot(1, 2, 1)
plt.imshow(image, cmap='gray')
plt.title('Original Image')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(label_image, cmap='nipy_spectral')
plt.title('Connected Components')
plt.axis('off')
plt.show()

print("Number of connected components:", num_components)
# Out:
# Number of connected components: 8
